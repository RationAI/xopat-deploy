# %%
from xopat import run_server, display

# %%
server = run_server(data_dir="path/to/slides")
# Out:
# ...
# Download complete.
# ...
# Download complete.
# Starting WSI-Service...
# WSI-Service is running.
# Starting xOpat...
# xOpat is running.

# %%
display(server, "slide")
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://127.0.0.1:9000/?slides=CMU-1.tiff"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
server.stop()
# Out:
# Stopping xOpat...
# xOpat stopped.
# Stopping WSI-Service...
# WSI-Service stopped.
